# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickes21/studies-notebooks/blob/main/2024/PUCPR/MFF/Aula_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sy
t = sy.Symbol('t')
f = t**2*sy.cos(t)
sy.integrate(f)
sy.plot(f, xlim=[0,5])
