# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickes21/studies-notebooks/blob/main/2024/PUCPR/MFF/Substitutiva_RA1_Individual_Ter%C3%A7a_2024_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3# Avaliação De Recuperação INDIVIDUAL RA1 - 2024-1 (substitutiva)
#
# **Antes de começar, leia estas instruções cuidadosamente.**
# Esta avaliação é individual. Você poderá consultar qualquer fonte disponível na biblioteca, suas anotações ou na internet. Mas, não poderá consultar outras pessoas.
#
# Não existirão prorrogações de prazo de entrega.
#
# **Trabalhos contendo partes idênticas entregues por pessoas, diferentes, serão zerados.**
#
# Todos os trabalhos serão entregues em uma cópia deste caderno de atividades na forma de um link postado no AVA da instituição (Canvas). Todos os enunciados devem ser preservados e você deverá inserir uma célula de textos com o **seu nome**, logo após esta célula de texto de instruções.
#
# Qualquer alteração do caderno contendo as suas respostas que seja registrada após a data de postagem provocará a anulação da avaliação.
#
# Você poderá usar, neste notebook, apenas a linguagem python limitada ao uso das seguintes bibliotecas: numpy, sympy, matplotlib, ipWidgets e IPython. Todo e qualquer gráfico deverá ser criado usando o Python.
#
# Entrega será realizada com a postagem de um link para um ambiente de execução, no AVA da institução. Neste link o seu caderno deve permitir ser executado (permissão de leitor). Serão aceitos links diretos ao ambiente do Google Colaboratory, ou Links a um caderno do Google Colaboratory que tenha sido salvo pelo próprio Google Colaboratory no GitHub. Links para outro ambiente, ou que requeiram qualquer tipo de download, cliques extras, ou ainda, que requeiram aprovação para acesso, provocarão o zeramento desta avaliação.
#
# Todas as suas simplificações e considerações serão levadas em consideração. Contudo, lembre-se que estas questões devem ser resolvidas com álgebra formal e apenas álgebra.
#
# Se você encontrar algo errado nesta avaliação simplesmente anote suas observações na própria questão. Suas observações serão consideradas durante a avaliação e, em caso de pertinência, poderão encejar a anulação do item, ou questão, a critério do professor.
#
# Não é permitido usar qualquer técnica matemática baseada em derivação, cálculo numérico, séries de Taylor ou Leibntz, ou que fuja dos conteúdos apresenados em aula referentes ao estudo dos conteúdos referentes a esta avaliação.
#
# Esta avaliação aborda os conteúdos referentes a limites, fórmula das diferenças finitas e tangentes.
#
# **Lembrem-se a interpretação faz parte da questão.**

# %% [markdown]
# ### Nome: Vitor Vitoriano Santana de Oliveira

# %% [markdown]
# ## Questões
# Usando apenas álgebra encontre o limites solicitados a seguir e faça uma análise dos resultados encontrados. Para fazer a análise você pode usar as ferramentas que desejar, desde que seja possível verificar a validade das suas afirmações usando apenas este caderno de avaliação.
#
# Lembre-se você deve usar notação matemática na sua resposta. O que implica no uso de Latex nas células de texto deste caderno de avaliação.
#
# Observe que o cálculo do valor de tendência do limite, usando uma calculadora, site, ou ferramenta qualquer, por si só não pode ser usado como argumento na sua análise. Isso quer dizer que justificativas como o limite é $w$ porque o Sympy disse que era esse valor, não serão aceitas.
#
# ### Exercício 1
# $$ \lim_{x \to 0} \frac{\sqrt{x+9} - 3}{x} $$
#
# ### Exercício 2
# $$ \lim_{x \to \infty} \frac{25x + 7}{\sqrt{5x^2 + 2}} $$
#
# ### Exercício 3
# $$
# \lim_{x \to 1} f(x) \text{ onde } f(x) = \begin{cases}
# 2x+1 & x \leq 1 \\
# x^2 + 1 & x > 1
# \end{cases}
# $$
#
# ### Exercício 4
# $$\lim_{x \to -\infty} (\sqrt{x^2 - x} - x)$$
#
# **Atenção**: o sympy parece não calcular este limite corretamente.
#
# ### Exercício 5
# $$ \lim_{x \to \infty} \frac{4x^2 + 3x - 5}{2x^2 - x + 1} $$
#
# **Rúbrica de avaliação**: cada limite corretamente determinado com a algebra demonstrada em notação matemática 1 ponto; cada análise consistente 1 ponto. Total 2 pontos por questão implicando em, no máximo 10 pontos.

# %% [markdown]
# As análises podem ser feitas por meio da análise gráfica, ou da ánálise dos limites laterais (aproximações pela esquerda e pela direita. Serão avaliadas de acordo com o que for apresentado por cada aluno.

# %% [markdown]
# ###Resposta 1
#
# Para resolver este limite, usamos as propriedades da radiciação e exponenciação:
#
# $$\lim_{{x \to 0}}  \frac{\sqrt{x+9} - 3}{x}=\frac{\sqrt{x+9} - 3}{x}\cdot\frac{\sqrt{x+9} + 3}{\sqrt{x+9} + 3}=\frac{x}{x(\sqrt{x+9}+3)}$$
# Após simplificar obtivemos o seguinte:
# $$\lim_{{x \to 0}}  \frac{x}{x(\sqrt{x+9}+3)}=\frac{1}{\sqrt{x+9}+3}$$
# Substituímos o valor para o qual tende $x$, ou seja 0:
# $$\frac{1}{\sqrt{0+9}+3}=\frac{1}{6}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and the limit value
def f(x):
    return (np.sqrt(x + 9) - 3) / x

x = np.linspace(-8.9, 10, 1000)  # expanded range to the right and avoid division by zero at x=0
y = f(x)

# Preparar o gráfico novamente com o novo intervalo
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$\frac{\sqrt{x+9} - 3}{x}$')
plt.axhline(y=1/6, color='r', linestyle='--', label=r'Limite $\frac{1}{6}$')
plt.axvline(x=0, color='k', linestyle='--', label='x=0')

# Marcar o limite
plt.scatter(0, 1/6, color='red')
plt.text(0, 1/6, '  (0, 1/6)', verticalalignment='bottom')

# Aprimorar o gráfico
plt.title(r'Gráfico expandido de $\frac{\sqrt{x+9} - 3}{x}$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.ylim(-0.20, 1)  # limitando o eixo y para uma melhor visualização
plt.grid(True)

# Exibir gráfico
plt.show()

# %% [markdown]
# - No intervalo analisado a função permanece contínua e o limite foi destacado

# %% [markdown]
# ### Resposta 2
#
# $$ \lim_{x \to \infty} \frac{25x + 7}{\sqrt{5x^2 + 2}} $$
#
# Para lidar com este limite, começamos dividindo o numerador e o denominador pelo termo de maior grau no denominador, que é $x$ no numerador e $x$ no denominador. No entanto, a raiz quadrada no denominador requer uma atenção especial:
#
# Dentro da raiz quadrada, $x^2$ é o termo dominante. Portanto, podemos fatorar $x^2$ de dentro da raiz:
#
# $$ \sqrt{5x^2 + 2} = \sqrt{x^2(5 + \frac{2}{x^2})} = x\sqrt{5 + \frac{2}{x^2}} $$
#
# Como $x$ tende ao infinito, o termo $\frac{2}{x^2}$ tende a zero, simplificando a expressão sob a raiz quadrada para $\sqrt{5}$:
#
# $$ \lim_{x \to \infty} x\sqrt{5 + \frac{2}{x^2}} = x\sqrt{5} $$
#
# Com isso, podemos reescrever o limite original como:
#
# $$ \lim_{x \to \infty} \frac{25x + 7}{\sqrt{5x^2 + 2}} = \lim_{x \to \infty} \frac{25x + 7}{x\sqrt{5}} = \lim_{x \to \infty} \frac{25x + 7}{x\sqrt{5}} = \lim_{x \to \infty} \frac{25 + \frac{7}{x}}{\sqrt{5}} $$
#
# À medida que $x$ tende ao infinito, $\frac{7}{x}$ tende a zero, deixando-nos com:
#
# $$ \frac{25}{\sqrt{5}} = \frac{25\sqrt{5}}{5} = 5\sqrt{5} $$
#
# Portanto, o limite é:
#
# $$ \lim_{x \to \infty} \frac{25x + 7}{\sqrt{5x^2 + 2}} = 5\sqrt{5} $$
#
#
# Podemos visualizar essa função e seu comportamento conforme $x$ se aproxima do infinito, utilizando um gráfico.
#
# Este gráfico mostra que, conforme $x$ se torna muito grande, a função se aproxima do limite $5\sqrt{5}$, validando nosso cálculo.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return (25*x + 7) / np.sqrt(5*x**2 + 2)

x = np.linspace(1, 100, 400)  # Avoid division by zero and focus on large x values
y = f(x)

# Plot the function and the limit
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$\frac{25x + 7}{\sqrt{5x^2 + 2}}$')
plt.axhline(y=5*np.sqrt(5), color='r', linestyle='--', label=r'Limite $5\sqrt{5}$')
plt.title('Comportamento de $\\frac{25x + 7}{\sqrt{5x^2 + 2}}$ enquanto $x \to \infty$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Resposta 3
#
# 1. Para $ x \leq 1 :  f(x) = 2x + 1 $
# 2. Para $ x > 1 :  f(x) = x^2 + 1 $
#
# ### Limite pela Esquerda $ x \to 1^- $
# Quando $ x $ se aproxima de 1 pela esquerda $ x \to 1^- $, utilizamos a expressão $ f(x) = 2x + 1 $:
#
# $$
# \lim_{x \to 1^-} f(x) = \lim_{x \to 1^-} (2x + 1) = 2 \times 1 + 1 = 3
# $$
#
# ### Limite pela Direita $ x \to 1^+ $
# Quando $ x $ se aproxima de 1 pela direita $ x \to 1^+ $, utilizamos a expressão $ f(x) = x^2 + 1 $:
#
# $$
# \lim_{x \to 1^+} f(x) = \lim_{x \to 1^+} (x^2 + 1) = 1^2 + 1 = 2
# $$
#
# Os limites pela esquerda e pela direita em $x = 1 $ são diferentes:
#
# - $ \lim_{x \to 1^-} f(x) = 3 $
# - $ \lim_{x \to 1^+} f(x) = 2 $
#
# Dado que os limites laterais não são iguais, o limite $ \lim_{x \to 1} f(x) $ não existe. Além disso, isso implica que a função $ f(x) $ não é contínua em $x = 1 $.
#
#
#
# Este gráfico ajudará a visualizar os limites laterais em $ x = 1 $, onde a função muda de comportamento.
#
# A análise do limite mostra que $ \lim_{x \to 1} f(x) $ não existe devido à descontinuidade da função nesse ponto.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir a função por partes
def f(x):
    return np.where(x <= 1, 2*x + 1, x**2 + 1)

x = np.linspace(0, 2, 400)  # define um intervalo de x de 0 a 2
y = f(x)

# Criar o gráfico
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x)')
plt.scatter(1, 3, color='blue', label='Limite à esquerda (3)', zorder=5)
plt.scatter(1, 2, color='red', label='Limite à direita (2)', zorder=5)
plt.title('Gráfico de f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axvline(x=1, color='gray', linestyle='--', label='x=1')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Resposta 4
# $$\lim_{x \to -\infty} (\sqrt{x^2 - x} - x)$$
#
# Para facilitar a simplificação, vamos multiplicar e dividir a expressão por sua conjugada para eliminar a raiz quadrada na diferença. Isso é útil para simplificar termos sob a raiz.
#
# $$ \lim_{x \to -\infty} (\sqrt{x^2 - x} - x) = \lim_{x \to -\infty} \left(\sqrt{x^2 - x} - x\right) \cdot \frac{\sqrt{x^2 - x} + x}{\sqrt{x^2 - x} + x} $$
#
# Expandindo o numerador usando a diferença de quadrados:
#
# $$ \lim_{x \to -\infty} \frac{(\sqrt{x^2 - x})^2 - x^2}{\sqrt{x^2 - x} + x} = \lim_{x \to -\infty} \frac{x^2 - x - x^2}{\sqrt{x^2 - x} + x} = \lim_{x \to -\infty} \frac{-x}{\sqrt{x^2 - x} + x} $$
#
# Vamos analisar o termo $\sqrt{x^2 - x}$. Sabendo que $x$ é muito grande e negativo, podemos aproximá-lo por $\sqrt{x^2}$, mas precisamos ajustar para a negatividade de $x$ e o termo $-x$:
#
# $$ \sqrt{x^2 - x} \approx \sqrt{x^2(1 - \frac{1}{x})} = |x|\sqrt{1 - \frac{1}{x}} $$
#
# Quando $x$ é negativo, $|x| = -x$, e como $x \to -\infty$, $\sqrt{1 - \frac{1}{x}} \to 1$:
#
#
# $$ \sqrt{x^2 - x} \approx -x $$
#
# Substituindo de volta na expressão do limite, obtemos:
#
# $$ \lim_{x \to -\infty} \frac{-x}{-x - x} = \lim_{x \to -\infty} \frac{-x}{-2x} = \lim_{x \to -\infty} \frac{1}{2} = \frac{1}{2} $$
#
# Portanto, o limite é:
# $$\lim_{x \to -\infty} (\sqrt{x^2 - x} - x) = \frac{1}{2}$$
#
# Podemos visualizar esse comportamento usando um gráfico para a função conforme $x$ se aproxima de $-\infty$.
#
# Este gráfico deve mostrar que, à medida que $x$ se torna muito grande (negativamente), a função se aproxima de $\frac{1}{2}$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return np.sqrt(x**2 - x) - x

x = np.linspace(-100, -1, 400)  # Focus on large negative x values
y = f(x)

# Plot the function and the limit
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$\sqrt{x^2 - x} - x$')
plt.axhline(y=0.5, color='r', linestyle='--', label=r'Limite $\frac{1}{2}$')
plt.title('Comportamento de $\sqrt{x^2 - x} - x$ enquanto $x \to -\infty$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Resposta 5
# $$ \lim_{x \to \infty} \frac{4x^2 + 3x - 5}{2x^2 - x + 1} $$
#
# Nesta expressão, tanto o numerador quanto o denominador são polinômios de grau 2. Portanto, os termos dominantes em ambos são os termos $x^2$. Podemos simplificar o limite dividindo todos os termos do numerador e do denominador pelo maior grau de $x$ presente, que é $x^2$:
#
# $$ \lim_{x \to \infty} \frac{4x^2 + 3x - 5}{2x^2 - x + 1} = \lim_{x \to \infty} \frac{4 + \frac{3}{x} - \frac{5}{x^2}}{2 - \frac{1}{x} + \frac{1}{x^2}} $$
#
# À medida que $x$ tende ao infinito, os termos $\frac{3}{x}$, $\frac{5}{x^2}$, $\frac{1}{x}$, e $\frac{1}{x^2}$ tendem a zero. Isto nos deixa apenas com os coeficientes dos termos $x^2$ no numerador e no denominador:
#
# $$ \lim_{x \to \infty} \frac{4}{2} = 2 $$
#
# Portanto, o limite é:
#
# $$ \lim_{x \to \infty} \frac{4x^2 + 3x - 5}{2x^2 - x + 1} = 2 $$
#
#
# Este gráfico demonstrará que, à medida que $x$ se torna muito grande, a função se aproxima do limite de 2, confirmando o cálculo realizado.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return (4*x**2 + 3*x - 5) / (2*x**2 - x + 1)

x = np.linspace(1, 100, 400)  # Avoid division by zero and focus on large x values
y = f(x)

# Plot the function and the limit
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$\frac{4x^2 + 3x - 5}{2x^2 - x + 1}$')
plt.axhline(y=2, color='r', linestyle='--', label=r'Limite $2$')
plt.title('Comportamento de $\\frac{4x^2 + 3x - 5}{2x^2 - x + 1}$ enquanto $x \to \infty$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
